# %% [markdown]
# <a href="https://colab.research.google.com/github/vasanthk77/Machine_learning/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a=pd.read_csv("Churn_Modelling.csv")

# %%
df=pd.DataFrame(a)

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
a=pd.get_dummies(df['Geography'],drop_first=True)
a1=pd.get_dummies(df['Gender'],drop_first=True)

# %%
df1=pd.concat([df,a,a1],axis='columns')

# %%
df1.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Germany  Spain  Male
# 0        101348.88       1        0      0     0
# 1        112542.58       0        0      1     0
# ...

# %%
df1.drop(['Gender'],axis='columns',inplace=True)

# %%
df1.drop(['Geography'],axis='columns',inplace=True)

# %%
df1.drop(['CustomerId'],axis='columns',inplace=True)
df1.drop(['Surname'],axis='columns',inplace=True)
df1.drop(['RowNumber'],axis='columns',inplace=True)

# %%
df1.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Germany  Spain  Male
# 0               1        101348.88       1        0      0     0
# 1               1        112542.58       0        0      1     0
# 2               0        113931.57       1        0      0     0
# 3               0         93826.63       0        0      0     0
# 4               1         79084.10       0        0      1     0

# %%
X=df1.drop(['Exited'],axis='columns')

# %%
y=df1.Exited

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train
# Out:
# array([[-0.34459497, -0.65674999, -0.34217046, ..., -0.57559072,
#          1.73073215, -1.09823226],
#        [-0.09518109, -0.46637979,  0.69816249, ...,  1.73734559,
#         -0.57779016, -1.09823226],
#        [-0.94734518, -0.56156489,  0.35138484, ..., -0.57559072,
#         -0.57779016,  0.91055421],
#        ...,
#        [ 0.86090545, -0.08563939, -1.38250341, ..., -0.57559072,
#         -0.57779016, -1.09823226],
#        [ 0.15423279,  0.39028611,  1.04494014, ..., -0.57559072,
#         -0.57779016,  0.91055421],
#        [ 0.46600014,  1.1517669 , -1.38250341, ...,  1.73734559,
#         -0.57779016,  0.91055421]])

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix

# %%
cm=confusion_matrix(y_test,y_pred)
print(cm)
cr=classification_report(y_test,y_pred)
print(cr)
accuracy=accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# [[2318   98]
#  [ 468  116]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      2416
#            1       0.54      0.20      0.29       584
#
#     accuracy                           0.81      3000
#    macro avg       0.69      0.58      0.59      3000
# weighted avg       0.78      0.81      0.77      3000
#
# 0.8113333333333334
